# %% [markdown]
# ### Alphabet Soup Charity Optimization Model 3

# %%
# %pip install keras-tuner --upgrade
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn import __SKLEARN_SETUP__
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
csv_path = 'Resources/charity_data.csv'


#  Import and read the charity_data.csv.
application_df = pd.read_csv(csv_path)
application_df.head()
# Out:
# Requirement already satisfied: keras-tuner in c:\users\myche\anaconda_updated\lib\site-packages (1.3.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\myche\anaconda_updated\lib\site-packages (from keras-tuner) (2.28.1)
# Requirement already satisfied: packaging in c:\users\myche\anaconda_updated\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: tensorflow>=2.0 in c:\users\myche\anaconda_updated\lib\site-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: kt-legacy in c:\users\myche\anaconda_updated\lib\site-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: ipython in c:\users\myche\anaconda_updated\lib\site-packages (from keras-tuner) (7.31.1)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (63.4.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.51.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.21.5)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (23.3.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.31.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.7.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: pygments in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (2.11.2)
# Requirement already satisfied: decorator in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (0.18.1)
# Requirement already satisfied: backcall in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: colorama in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\myche\anaconda_updated\lib\site-packages (from ipython->keras-tuner) (0.1.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\myche\anaconda_updated\lib\site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\myche\anaconda_updated\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\myche\anaconda_updated\lib\site-packages (from requests->keras-tuner) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\myche\anaconda_updated\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\myche\anaconda_updated\lib\site-packages (from requests->keras-tuner) (1.26.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\myche\anaconda_updated\lib\site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\myche\anaconda_updated\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\myche\anaconda_updated\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\myche\anaconda_updated\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\myche\anaconda_updated\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\myche\anaconda_updated\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\myche\anaconda_updated\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\myche\anaconda_updated\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\myche\anaconda_updated\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\myche\anaconda_updated\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.2.2)
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_counts = application_df['APPLICATION_TYPE'].value_counts()
app_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
application_types_to_replace = list(app_counts[app_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(
        app, "Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_gt1 = class_counts.loc[class_counts > 1]
class_counts_gt1.head()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
classifications_to_replace = list(class_counts[class_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(
        cls, "Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_numeric = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_numeric.drop(['IS_SUCCESSFUL'], axis=1)
y = application_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=58)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Create a method that creats a new Sequential model with hyperparameter options

def create_model(hp):
    nn_model3 = tf.keras.models.Sequential()

    # Allow kerastuner to devide which activation function to use in hidden layers
    activation = hp.Choice('activation', ['sigmoid', 'tanh'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model3.add(tf.keras.layers.Dense(units=hp.Int('first_units', 
        min_value=1,
        max_value=5,
        step=5), activation=activation, input_dim=43))
    
    # Allow kerastuner to decide number of hidden layers and neurons to add to hidden layers
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model3.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=5,
            step=5),
            activation=activation))
        
    nn_model3.add(tf.keras.layers.Dense(units=1, activation='relu'))

    # Compile the model
    nn_model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return nn_model3

# Create kerastuner
import keras_tuner as kt

tuner = kt.Hyperband(create_model,
                     objective='val_accuracy',
                     max_epochs=5,
                     hyperband_iterations=2)


# Search for the best hyperparameters
tuner.search(X_train_scaled, y_train, epochs=5, validation_data=(X_test_scaled, y_test))

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=3)[0]

# Build the model with the best hyperparameters
model_3 = create_model(best_hps)

# Train the model
fit_model = model_3.fit(X_train_scaled, y_train, epochs=5)
# Out:
# INFO:tensorflow:Reloading Tuner from .\untitled_project\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 804/804 [==============================] - 30s 9ms/step - loss: 0.9112 - accuracy: 0.6766
# Epoch 2/5
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5725 - accuracy: 0.7222
# Epoch 3/5
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5787 - accuracy: 0.7138
# Epoch 4/5
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5756 - accuracy: 0.7115
# Epoch 5/5
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5630 - accuracy: 0.7274

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective='val_accuracy',
    max_epochs=5,
    hyperband_iterations=2)
# Out:
# INFO:tensorflow:Reloading Tuner from .\untitled_project\tuner0.json

# %%
# Run the kerastuner search for the best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled, y_test))
# Out:
# Search: Running Trial #147
#
# Value             |Best Value So Far |Hyperparameter
# sigmoid           |tanh              |activation
# 1                 |26                |first_units
# 1                 |5                 |num_layers
# 16                |6                 |units_0
# 16                |21                |units_1
# 11                |6                 |units_2
# 26                |16                |units_3
# 1                 |26                |units_4
# 4                 |10                |tuner/epochs
# 0                 |4                 |tuner/initial_epoch
# 1                 |2                 |tuner/bracket
# 0                 |2                 |tuner/round
#
# Epoch 1/4
# 804/804 [==============================] - 70s 63ms/step - loss: 0.6666 - accuracy: 0.6140 - val_loss: 0.6142 - val_accuracy: 0.7109
# Epoch 2/4
# 804/804 [==============================] - 47s 55ms/step - loss: 0.5924 - accuracy: 0.7191 - val_loss: 0.5831 - val_accuracy: 0.7201
# Epoch 3/4
# 804/804 [==============================] - 21s 23ms/step - loss: 0.5790 - accuracy: 0.7265 - val_loss: 0.5818 - val_accuracy: 0.7200
# Epoch 4/4
# 798/804 [============================>.] - ETA: 0s - loss: 0.5777 - accuracy: 0.7274
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5968\219168988.py in <module>
#       1 # Run the kerastuner search for the best hyperparameters
# ----> 2 tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled, y_test))
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     224
#     225             self.on_trial_begin(trial)
# --> 226             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     227             self.on_trial_end(trial)
#     228         self.on_search_end()
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\engine\base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     264     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     265         try:
# --> 266             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     267             trial.status = trial_module.TrialStatus.COMPLETED
#     268             return
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\engine\base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     229
#     230     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 231         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     232         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     233             self.oracle.objective.name
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\tuners\hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     417             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     418             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 419         return super().run_trial(trial, *fit_args, **fit_kwargs)
#     420
#     421     def _build_hypermodel(self, hp):
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\engine\tuner.py in run_trial(self, trial, *args, **kwargs)
#     285             callbacks.append(model_checkpoint)
#     286             copied_kwargs["callbacks"] = callbacks
# --> 287             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     288
#     289             histories.append(obj_value)
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\engine\tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     212         hp = trial.hyperparameters
#     213         model = self._try_build(hp)
# --> 214         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     215         tuner_utils.validate_trial_results(
#     216             results, self.oracle.objective, "HyperModel.fit()"
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras_tuner\engine\hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     142             If return a float, it should be the `objective` value.
#     143         """
# --> 144         return model.fit(*args, **kwargs)
#     145
#     146
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2044                             logs = tmp_logs
#    2045                             end_step = step + data_handler.step_increment
# -> 2046                             callbacks.on_test_batch_end(end_step, logs)
#    2047
#    2048             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\callbacks.py in on_test_batch_end(self, batch, logs)
#     496         """
#     497         if self._should_call_test_batch_hooks:
# --> 498             self._call_batch_hook(ModeKeys.TEST, "end", batch, logs=logs)
#     499
#     500     def on_predict_batch_begin(self, batch, logs=None):
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     321             self._call_batch_begin_hook(mode, batch, logs)
#     322         elif hook == "end":
# --> 323             self._call_batch_end_hook(mode, batch, logs)
#     324         else:
#     325             raise ValueError(
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     344             self._batch_times.append(batch_time)
#     345
# --> 346         self._call_batch_hook_helper(hook_name, batch, logs)
#     347
#     348         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     389             start_time = time.time()
#     390
# --> 391         logs = self._process_logs(logs, is_batch_hook=True)
#     392         for callback in self.callbacks:
#     393             hook = getattr(callback, hook_name)
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\callbacks.py in _process_logs(self, logs, is_batch_hook)
#     296         if is_batch_hook and self._batch_hooks_support_tf_logs:
#     297             return logs
# --> 298         return tf_utils.sync_to_numpy_or_python_type(logs)
#     299
#     300     def append(self, callback):
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     663         return t.item() if np.ndim(t) == 0 else t
#     664
# --> 665     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     666
#     667
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     661         if not isinstance(t, (np.ndarray, np.generic)):
#     662             return t
# --> 663         return t.item() if np.ndim(t) == 0 else t
#     664
#     665     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# <__array_function__ internals> in ndim(*args, **kwargs)
#
# c:\Users\myche\Anaconda_updated\lib\site-packages\numpy\core\fromnumeric.py in ndim(a)
#    3158     """
#    3159     try:
# -> 3160         return a.ndim
#    3161     except AttributeError:
#    3162         return asarray(a).ndim
#
# KeyboardInterrupt:

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 26,
#  'num_layers': 5,
#  'units_0': 6,
#  'units_1': 21,
#  'units_2': 6,
#  'units_3': 16,
#  'units_4': 26,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0098'}

# %%
# Evaluate the best model against full test data
best_model = tuner.get_best_models(3)
for model in best_model:
    model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5968\540173300.py in <module>
#       2 best_model = tuner.get_best_models(3)
#       3 for model in best_model:
# ----> 4     model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
#       5 print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
#
# AttributeError: 'list' object has no attribute 'evaluate'

# %%
# Export our model to HDF5 file
# Define the filename
filename = 'H5_Files/AlphabetSoupCharity_Optimization3.h5'


# Save the model to a HDF5 file
best_model.save(filename)
